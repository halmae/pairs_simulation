# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
from signals import *
from utility_functions import *
from visualization import *

# %%
# 실행
returns_bt, returns_in, returns_out, metrics = visualize_all_periods('BTC', 'ETH', tf='1m', window_size=120)

# 상세 성과 지표 출력
print("\nDetailed Performance Metrics:")
for period, stats in metrics.items():
    print(f"\n{period} Period:")
    for metric, value in stats.items():
        print(f"  {metric}: {value}")
# Out:
# /root/sj/pairs/signals.py:50: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   current_signal = signals[i]
# /root/sj/pairs/signals.py:54: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   entry_coin1_price = coin1_prices[i]
# /root/sj/pairs/signals.py:55: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   entry_coin2_price = coin2_prices[i]
# /root/sj/pairs/signals.py:61: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   returns[i] = (coin2_prices[i]/entry_coin2_price) - (coin1_prices[i]/entry_coin1_price)
# /root/sj/pairs/signals.py:61: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   returns[i] = (coin2_prices[i]/entry_coin2_price) - (coin1_prices[i]/entry_coin1_price)
# /root/sj/pairs/signals.py:59: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   returns[i] = (coin1_prices[i]/entry_coin1_price) - (coin2_prices[i]/entry_coin2_price)
# /root/sj/pairs/signals.py:59: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   returns[i] = (coin1_prices[i]/entry_coin1_price) - (coin2_prices[i]/entry_coin2_price)
# Detailed Performance Metrics:
#
# Backtest Period:
#   Total Return (%): 72.32
#   Annualized Return (%): 46.95
#   Sharpe Ratio: nan
#   Sortino Ratio: 0.26
#   Max Drawdown (%): 129.17
#
# In-Sample Period:
#   Total Return (%): 15.1
#   Annualized Return (%): 52.82
#   Sharpe Ratio: nan
#   Sortino Ratio: nan
#   Max Drawdown (%): inf
#
# Out-Sample Period:
#   Total Return (%): 0.88
#   Annualized Return (%): 5.59
#   Sharpe Ratio: nan
#   Sortino Ratio: 0.0
#   Max Drawdown (%): 475.14
